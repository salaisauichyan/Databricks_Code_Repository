# %% [markdown]
# #Task1: <br>  Document the Notebook Using mark down %md <br>
# - A good Title <br>
# - Description of the task <br>
# - Your name in some color <br>
# - Bring our Team photo from the given url "https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg" <br>
# - Use headings, bold, italics appropriately. <br>
# # Databricks Commands
# _Let's Starts To Work With Commands Using Usecases <br>_
# **$${\color{blue}Salai\ Sauichyan}$$**

# %% [markdown]
# #Task2: <br>
# ##Create a volume namely usage_metrics using sql magic command %sql <br>

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %% [markdown]
# ### Adding Our Team Picture Using Url Command
# ![logo](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %% [markdown]
# # Task3: <br>
# Create a child notebook "4_child_nb_dataload" and write code to load data, Using the requests library, perform api call to pull data from "https://public.tableau.com/app/sample-data/mobile_os_usage.csv" into a python variable using the magic command %py and write the data into the created volume "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv" using the above variable.text using the magic command dbutils.fs.put("volume",variable.text,overwrite=True) <br>
# - Creating a child notebook path ......    to load data<br>
# - In this child notebook using python with req lib %py to call the url and stored the repo in variable<br>
# - Text into the unity catalog volume using ....

# %% [markdown]
# # Task4:
# ### Call the notebook 4_child_nb_dataload using the magic command %run

# %%
# %run
/Workspace/Users/sauichyansalai@gmail.com/Databricks_Code_Repository/Databricks_Workouts_2025/Databricks_workouts/4_child_nb_dataload

# %% [markdown]
# #Task5:<br>
# ###list the file is created in the given volume or not and do the head of this file using fs magic command %fs

# %%
# %fs
ls "/Volumes/workspace/default/usage_metrics"

# %%
# %fs head dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %% [markdown]
# #Task6:<br>
# ###Create a pyspark dataframe df1 reading the data from the above file using pyspark magic command %python

# %%
# %python
df1 = spark.read.csv("dbfs:/volumes/workspace/default/usage_metrics/mobile_os_usage.csv", header=True, inferSchema=True)
df1.show(5)
df1.printSchema()

# %% [markdown]
# #Task7:<br>
# ###  Write the above dataframe df1 data into a databricks table called 'default.mobile_os_usage' using pyspark magic command %python

# %%
# %python
df1.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# %% [markdown]
# #Task8:<br>
# ### Write sql query to display the data loaded into the table 'default.mobile_os_usage' using the pyspark magic command %python

# %%
# %sql
SELECT *
FROM default.mobile_os_usage LIMIT 10;

# %% [markdown]
# #Task9:<br>
# ### Create a python function to convert the given input to upper case

# %%
Task10: Install pandas library using the pip python magic command %pip

Task11: Import pandas, using pandas read_csv and display the output using the magic command %python

Task12: echo "Magic commands tasks completed" using the linux shell magic command %sh
